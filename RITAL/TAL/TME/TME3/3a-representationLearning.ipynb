# %% [markdown]
# # NLP & representation learning: Neural Embeddings, Text Classification
#
#
# To use statistical classifiers with text, it is first necessary to vectorize the text. In the first practical session we explored the **Bag of Word (BoW)** model.
#
# Modern **state of the art** methods uses  embeddings to vectorize the text before classification in order to avoid feature engineering.
#
# ## [Dataset](https://thome.isir.upmc.fr/classes/RITAL/json_pol)
#
#
# ## "Modern" NLP pipeline
#
# By opposition to the **bag of word** model, in the modern NLP pipeline everything is **embeddings**. Instead of encoding a text as a **sparse vector** of length $D$ (size of feature dictionnary) the goal is to encode the text in a meaningful dense vector of a small size $|e| <<< |D|$.
#
#
# The raw classification pipeline is then the following:
#
# ```
# raw text ---|embedding table|-->  vectors --|Neural Net|--> class
# ```
#
#
# ### Using a  language model:
#
# How to tokenize the text and extract a feature dictionnary is still a manual task. To directly have meaningful embeddings, it is common to use a pre-trained language model such as `word2vec` which we explore in this practical.
#
# In this setting, the pipeline becomes the following:
# ```
#
# raw text ---|(pre-trained) Language Model|--> vectors --|classifier (or fine-tuning)|--> class
# ```
#
#
# - #### Classic word embeddings
#
#  - [Word2Vec](https://arxiv.org/abs/1301.3781)
#  - [Glove](https://nlp.stanford.edu/projects/glove/)
#
#
# - #### bleeding edge language models techniques (see next)
#
#  - [UMLFIT](https://arxiv.org/abs/1801.06146)
#  - [ELMO](https://arxiv.org/abs/1802.05365)
#  - [GPT](https://blog.openai.com/language-unsupervised/)
#  - [BERT](https://arxiv.org/abs/1810.04805)
#
#
#
#
#
#
# ### Goal of this session:
#
# 1. Train word embeddings on training dataset
# 2. Tinker with the learnt embeddings and see learnt relations
# 3. Tinker with pre-trained embeddings.
# 4. Use those embeddings for classification
# 5. Compare different embedding models
# 6. Pytorch first look: learn to generate text.

# %% [markdown]
# ## STEP 0: Loading data

# %%
import json
from collections import Counter

# Loading json
with open("ressources/json_pol",encoding="utf-8") as f:
    data = f.readlines()
    json_data = json.loads(data[0])
    train = json_data["train"]
    test = json_data["test"]
    

# Quick Check
counter_train = Counter((x[1] for x in train))
counter_test = Counter((x[1] for x in test))
print("Number of train reviews : ", len(train))
print("----> # of positive : ", counter_train[1])
print("----> # of negative : ", counter_train[0])
print("")
print(train[0])
print("")
print("Number of test reviews : ",len(test))
print("----> # of positive : ", counter_test[1])
print("----> # of negative : ", counter_test[0])

print("")
print(test[0])
print("")
# Out:
# Number of train reviews :  25000
# ----> # of positive :  12500
# ----> # of negative :  12500
#
# ["The undoubted highlight of this movie is Peter O'Toole's performance. In turn wildly comical and terribly terribly tragic. Does anybody do it better than O'Toole? I don't think so. What a great face that man has!<br /><br />The story is an odd one and quite disturbing and emotionally intense in parts (especially toward the end) but it is also oddly touching and does succeed on many levels. However, I felt the film basically revolved around Peter O'Toole's luminous performance and I'm sure I wouldn't have enjoyed it even half as much if he hadn't been in it.", 1]
#
# Number of test reviews :  25000
# ----> # of positive :  12500
# ----> # of negative :  12500
#
# ['Although credit should have been given to Dr. Seuess for stealing the story-line of "Horton Hatches The Egg", this was a fine film. It touched both the emotions and the intellect. Due especially to the incredible performance of seven year old Justin Henry and a script that was sympathetic to each character (and each one\'s predicament), the thought provoking elements linger long after the tear jerking ones are over. Overall, superior acting from a solid cast, excellent directing, and a very powerful script. The right touches of humor throughout help keep a "heavy" subject from becoming tedious or difficult to sit through. Lastly, this film stands the test of time and seems in no way dated, decades after it was released.', 1]

# %% [markdown]
# ## Word2Vec: Quick Recap
#
# **[Word2Vec](https://arxiv.org/abs/1301.3781) is composed of two distinct language models (CBOW and SG), optimized to quickly learn word vectors**
#
#
# given a random text: `i'm taking the dog out for a walk`
#
#
#
# ### (a) Continuous Bag of Word (CBOW)
#     -  predicts a word given a context
#
# maximizing `p(dog | i'm taking the ___ out for a walk)`
#
# ### (b) Skip-Gram (SG)
#     -  predicts a context given a word
#
#  maximizing `p(i'm taking the out for a walk | dog)`

# %% [markdown]
# ## STEP 1: train a language model (word2vec)
#
# Gensim has one of [Word2Vec](https://radimrehurek.com/gensim/models/word2vec.html) fastest implementation.
#
#
# ### Train:

# %%
# if gensim not installed yet
# ! pip install gensim

# %%
import gensim
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

text = [t.split() for t,p in train]

# the following configuration is the default configuration
w2v = gensim.models.word2vec.Word2Vec(sentences=text,
                                vector_size=100, window=5,               ### here we train a cbow model 
                                min_count=5,                      
                                sample=0.001, workers=3,
                                sg=1, hs=0, negative=5,        ### set sg to 1 to train a sg model
                                cbow_mean=1, epochs=5)
# Out:
# 2023-02-16 16:40:30,968 : INFO : collecting all words and their counts
# 2023-02-16 16:40:30,972 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2023-02-16 16:40:31,365 : INFO : PROGRESS: at sentence #10000, processed 2358544 words, keeping 155393 word types
# 2023-02-16 16:40:31,786 : INFO : PROGRESS: at sentence #20000, processed 4675912 words, keeping 243050 word types
# 2023-02-16 16:40:32,004 : INFO : collected 280617 word types from a corpus of 5844680 raw words and 25000 sentences
# 2023-02-16 16:40:32,004 : INFO : Creating a fresh vocabulary
# 2023-02-16 16:40:32,203 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=5 retains 49345 unique words (17.58% of original 280617, drops 231272)', 'datetime': '2023-02-16T16:40:32.203135', 'gensim': '4.3.0', 'python': '3.10.10 (main, Feb 16 2023, 11:11:15) [GCC 12.2.1 20221121 (Red Hat 12.2.1-4)]', 'platform': 'Linux-6.1.11-200.fc37.x86_64-x86_64-with-glibc2.36', 'event': 'prepare_vocab'}
# 2023-02-16 16:40:32,203 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=5 leaves 5517507 word corpus (94.40% of original 5844680, drops 327173)', 'datetime': '2023-02-16T16:40:32.203852', 'gensim': '4.3.0', 'python': '3.10.10 (main, Feb 16 2023, 11:11:15) [GCC 12.2.1 20221121 (Red Hat 12.2.1-4)]', 'platform': 'Linux-6.1.11-200.fc37.x86_64-x86_64-with-glibc2.36', 'event': 'prepare_vocab'}
# 2023-02-16 16:40:32,392 : INFO : deleting the raw counts dictionary of 280617 items
# 2023-02-16 16:40:32,399 : INFO : sample=0.001 downsamples 43 most-common words
# 2023-02-16 16:40:32,400 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 4268608.194985565 word corpus (77.4%% of prior 5517507)', 'datetime': '2023-02-16T16:40:32.400030', 'gensim': '4.3.0', 'python': '3.10.10 (main, Feb 16 2023, 11:11:15) [GCC 12.2.1 20221121 (Red Hat 12.2.1-4)]', 'platform': 'Linux-6.1.11-200.fc37.x86_64-x86_64-with-glibc2.36', 'event': 'prepare_vocab'}
# 2023-02-16 16:40:32,706 : INFO : estimated required memory for 49345 words and 100 dimensions: 64148500 bytes
# 2023-02-16 16:40:32,707 : INFO : resetting layer weights
# 2023-02-16 16:40:32,725 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-02-16T16:40:32.725040', 'gensim': '4.3.0', 'python': '3.10.10 (main, Feb 16 2023, 11:11:15) [GCC 12.2.1 20221121 (Red Hat 12.2.1-4)]', 'platform': 'Linux-6.1.11-200.fc37.x86_64-x86_64-with-glibc2.36', 'event': 'build_vocab'}
# 2023-02-16 16:40:32,725 : INFO : Word2Vec lifecycle event {'msg': 'training model with 3 workers on 49345 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2023-02-16T16:40:32.725889', 'gensim': '4.3.0', 'python': '3.10.10 (main, Feb 16 2023, 11:11:15) [GCC 12.2.1 20221121 (Red Hat 12.2.1-4)]', 'platform': 'Linux-6.1.11-200.fc37.x86_64-x86_64-with-glibc2.36', 'event': 'train'}
# 2023-02-16 16:40:33,759 : INFO : EPOCH 0 - PROGRESS: at 7.99% examples, 338883 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:40:34,788 : INFO : EPOCH 0 - PROGRESS: at 16.44% examples, 343322 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:40:35,795 : INFO : EPOCH 0 - PROGRESS: at 25.01% examples, 349661 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:40:36,796 : INFO : EPOCH 0 - PROGRESS: at 32.76% examples, 346012 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:40:37,800 : INFO : EPOCH 0 - PROGRESS: at 40.34% examples, 341254 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:40:38,808 : INFO : EPOCH 0 - PROGRESS: at 47.73% examples, 337656 words/s, in_qsize 6, out_qsize 0
# 2023-02-16 16:40:39,833 : INFO : EPOCH 0 - PROGRESS: at 54.75% examples, 331324 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:40:40,834 : INFO : EPOCH 0 - PROGRESS: at 61.76% examples, 327559 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:40:41,840 : INFO : EPOCH 0 - PROGRESS: at 70.20% examples, 329373 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:40:42,865 : INFO : EPOCH 0 - PROGRESS: at 77.01% examples, 324591 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:40:43,871 : INFO : EPOCH 0 - PROGRESS: at 83.86% examples, 321314 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:40:44,927 : INFO : EPOCH 0 - PROGRESS: at 90.54% examples, 317172 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:40:45,933 : INFO : EPOCH 0 - PROGRESS: at 96.45% examples, 312148 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:40:46,536 : INFO : EPOCH 0: training on 5844680 raw words (4269887 effective words) took 13.8s, 309200 effective words/s
# 2023-02-16 16:40:47,561 : INFO : EPOCH 1 - PROGRESS: at 6.35% examples, 272964 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:40:48,561 : INFO : EPOCH 1 - PROGRESS: at 12.87% examples, 275545 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:40:49,564 : INFO : EPOCH 1 - PROGRESS: at 19.75% examples, 281061 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:40:50,597 : INFO : EPOCH 1 - PROGRESS: at 26.46% examples, 280040 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:40:51,603 : INFO : EPOCH 1 - PROGRESS: at 32.90% examples, 279390 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:40:52,606 : INFO : EPOCH 1 - PROGRESS: at 39.48% examples, 279356 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:40:53,612 : INFO : EPOCH 1 - PROGRESS: at 46.19% examples, 281180 words/s, in_qsize 6, out_qsize 0
# 2023-02-16 16:40:54,623 : INFO : EPOCH 1 - PROGRESS: at 53.28% examples, 283297 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:40:55,648 : INFO : EPOCH 1 - PROGRESS: at 60.22% examples, 283713 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:40:56,671 : INFO : EPOCH 1 - PROGRESS: at 66.85% examples, 282675 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:40:57,680 : INFO : EPOCH 1 - PROGRESS: at 73.97% examples, 283582 words/s, in_qsize 6, out_qsize 0
# 2023-02-16 16:40:58,696 : INFO : EPOCH 1 - PROGRESS: at 80.72% examples, 283137 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:40:59,731 : INFO : EPOCH 1 - PROGRESS: at 87.68% examples, 283942 words/s, in_qsize 6, out_qsize 0
# 2023-02-16 16:41:00,747 : INFO : EPOCH 1 - PROGRESS: at 95.93% examples, 288573 words/s, in_qsize 6, out_qsize 0
# 2023-02-16 16:41:01,210 : INFO : EPOCH 1: training on 5844680 raw words (4268713 effective words) took 14.7s, 290978 effective words/s
# 2023-02-16 16:41:02,238 : INFO : EPOCH 2 - PROGRESS: at 7.62% examples, 326668 words/s, in_qsize 6, out_qsize 0
# 2023-02-16 16:41:03,259 : INFO : EPOCH 2 - PROGRESS: at 15.20% examples, 320895 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:04,297 : INFO : EPOCH 2 - PROGRESS: at 22.76% examples, 316947 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:05,340 : INFO : EPOCH 2 - PROGRESS: at 29.80% examples, 309936 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:06,354 : INFO : EPOCH 2 - PROGRESS: at 36.54% examples, 305808 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:07,354 : INFO : EPOCH 2 - PROGRESS: at 43.30% examples, 302605 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:08,355 : INFO : EPOCH 2 - PROGRESS: at 49.70% examples, 299358 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:09,362 : INFO : EPOCH 2 - PROGRESS: at 56.72% examples, 298505 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:10,368 : INFO : EPOCH 2 - PROGRESS: at 63.41% examples, 297690 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:11,383 : INFO : EPOCH 2 - PROGRESS: at 70.49% examples, 296400 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:12,397 : INFO : EPOCH 2 - PROGRESS: at 77.54% examples, 296036 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:13,416 : INFO : EPOCH 2 - PROGRESS: at 84.35% examples, 295109 words/s, in_qsize 6, out_qsize 0
# 2023-02-16 16:41:14,424 : INFO : EPOCH 2 - PROGRESS: at 90.70% examples, 293336 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:15,446 : INFO : EPOCH 2 - PROGRESS: at 97.13% examples, 291599 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:15,877 : INFO : EPOCH 2: training on 5844680 raw words (4269093 effective words) took 14.7s, 291100 effective words/s
# 2023-02-16 16:41:16,882 : INFO : EPOCH 3 - PROGRESS: at 7.27% examples, 320160 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:17,892 : INFO : EPOCH 3 - PROGRESS: at 14.23% examples, 305122 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:18,895 : INFO : EPOCH 3 - PROGRESS: at 21.29% examples, 303091 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:19,905 : INFO : EPOCH 3 - PROGRESS: at 27.41% examples, 292884 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:20,907 : INFO : EPOCH 3 - PROGRESS: at 33.24% examples, 284186 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:21,948 : INFO : EPOCH 3 - PROGRESS: at 40.00% examples, 282793 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:22,961 : INFO : EPOCH 3 - PROGRESS: at 46.19% examples, 280766 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:23,974 : INFO : EPOCH 3 - PROGRESS: at 52.94% examples, 281115 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:24,995 : INFO : EPOCH 3 - PROGRESS: at 59.89% examples, 281879 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:26,012 : INFO : EPOCH 3 - PROGRESS: at 68.21% examples, 288322 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:27,043 : INFO : EPOCH 3 - PROGRESS: at 76.66% examples, 293411 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:28,062 : INFO : EPOCH 3 - PROGRESS: at 84.70% examples, 296879 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:29,080 : INFO : EPOCH 3 - PROGRESS: at 91.50% examples, 296410 words/s, in_qsize 6, out_qsize 0
# 2023-02-16 16:41:30,088 : INFO : EPOCH 3 - PROGRESS: at 99.26% examples, 298278 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:30,178 : INFO : EPOCH 3: training on 5844680 raw words (4269673 effective words) took 14.3s, 298614 effective words/s
# 2023-02-16 16:41:31,210 : INFO : EPOCH 4 - PROGRESS: at 7.46% examples, 318343 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:32,211 : INFO : EPOCH 4 - PROGRESS: at 15.40% examples, 327109 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:33,236 : INFO : EPOCH 4 - PROGRESS: at 23.43% examples, 329435 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:34,236 : INFO : EPOCH 4 - PROGRESS: at 30.95% examples, 327835 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:35,246 : INFO : EPOCH 4 - PROGRESS: at 38.93% examples, 330283 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:36,259 : INFO : EPOCH 4 - PROGRESS: at 46.88% examples, 331839 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:37,262 : INFO : EPOCH 4 - PROGRESS: at 55.11% examples, 334386 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:38,277 : INFO : EPOCH 4 - PROGRESS: at 63.07% examples, 334993 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:39,289 : INFO : EPOCH 4 - PROGRESS: at 70.01% examples, 328668 words/s, in_qsize 6, out_qsize 0
# 2023-02-16 16:41:40,338 : INFO : EPOCH 4 - PROGRESS: at 78.29% examples, 328884 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:41,365 : INFO : EPOCH 4 - PROGRESS: at 85.50% examples, 326539 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:42,391 : INFO : EPOCH 4 - PROGRESS: at 93.38% examples, 326919 words/s, in_qsize 5, out_qsize 0
# 2023-02-16 16:41:43,180 : INFO : EPOCH 4: training on 5844680 raw words (4269664 effective words) took 13.0s, 328421 effective words/s
# 2023-02-16 16:41:43,181 : INFO : Word2Vec lifecycle event {'msg': 'training on 29223400 raw words (21347030 effective words) took 70.5s, 302988 effective words/s', 'datetime': '2023-02-16T16:41:43.181237', 'gensim': '4.3.0', 'python': '3.10.10 (main, Feb 16 2023, 11:11:15) [GCC 12.2.1 20221121 (Red Hat 12.2.1-4)]', 'platform': 'Linux-6.1.11-200.fc37.x86_64-x86_64-with-glibc2.36', 'event': 'train'}
# 2023-02-16 16:41:43,181 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec<vocab=49345, vector_size=100, alpha=0.025>', 'datetime': '2023-02-16T16:41:43.181747', 'gensim': '4.3.0', 'python': '3.10.10 (main, Feb 16 2023, 11:11:15) [GCC 12.2.1 20221121 (Red Hat 12.2.1-4)]', 'platform': 'Linux-6.1.11-200.fc37.x86_64-x86_64-with-glibc2.36', 'event': 'created'}

# %%
# Worth it to save the previous embedding
w2v.save("W2v-movies.dat")
# You will be able to reload them:
# w2v = gensim.models.Word2Vec.load("W2v-movies.dat")
# and you can continue the learning process if needed
# Out:
# 2023-02-16 16:41:43,218 : INFO : Word2Vec lifecycle event {'fname_or_handle': 'W2v-movies.dat', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2023-02-16T16:41:43.218107', 'gensim': '4.3.0', 'python': '3.10.10 (main, Feb 16 2023, 11:11:15) [GCC 12.2.1 20221121 (Red Hat 12.2.1-4)]', 'platform': 'Linux-6.1.11-200.fc37.x86_64-x86_64-with-glibc2.36', 'event': 'saving'}
# 2023-02-16 16:41:43,220 : INFO : not storing attribute cum_table
# 2023-02-16 16:41:43,297 : INFO : saved W2v-movies.dat

# %% [markdown]
# ## STEP 2: Test learnt embeddings
#
# The word embedding space directly encodes similarities between words: the vector coding for the word "great" will be closer to the vector coding for "good" than to the one coding for "bad". Generally, [cosine similarity](https://en.wikipedia.org/wiki/Cosine_similarity) is the distance used when considering distance between vectors.
#
# KeyedVectors have a built in [similarity](https://radimrehurek.com/gensim/models/keyedvectors.html#gensim.models.keyedvectors.BaseKeyedVectors.similarity) method to compute the cosine similarity between words

# %%
# is great really closer to good than to bad ?
print("great and good:",w2v.wv.similarity("great","good"))
print("great and bad:",w2v.wv.similarity("great","bad"))
# Out:
# great and good: 0.78008837
# great and bad: 0.47419986

# %% [markdown]
# Since cosine distance encodes similarity, neighboring words are supposed to be similar. The [most_similar](https://radimrehurek.com/gensim/models/keyedvectors.html#gensim.models.keyedvectors.BaseKeyedVectors.most_similar) method returns the `topn` words given a query.

# %%
# The query can be as simple as a word, such as "movie"

# Try changing the word
w2v.wv.most_similar("movie",topn=5) # 5 most similar words
#w2v.wv.most_similar("awesome",topn=5)
#w2v.wv.most_similar("actor",topn=5)
# Out:
# [('film', 0.9325805306434631),
#  ('"film"', 0.8607557415962219),
#  ('"movie"', 0.7760202288627625),
#  ('programme', 0.7686837911605835),
#  ('movie...', 0.7646211981773376)]

# %% [markdown]
# But it can be a more complicated query
# Word embedding spaces tend to encode much more.
#
# The most famous exemple is: `vec(king) - vec(man) + vec(woman) => vec(queen)`

# %%
# What is awesome - good + bad ?
w2v.wv.most_similar(positive=["awesome","bad"],negative=["good"],topn=3)  

w2v.wv.most_similar(positive=["actor","woman"],negative=["man"],topn=3) # do the famous exemple works for actor ?


# Try other things like plurals for exemple.
# Out:
# [('actress', 0.8330235481262207),
#  ('actress,', 0.7358322739601135),
#  ('actress.', 0.6949314475059509)]

# %% [markdown]
# To test learnt "synctactic" and "semantic" similarities, Mikolov et al. introduced a special dataset containing a wide variety of three way similarities.

# %%
out = w2v.wv.evaluate_word_analogies("ressources/questions-words.txt",case_insensitive=True)  #original semantic syntactic dataset.
# Out:
# 2023-02-16 16:41:43,684 : INFO : Evaluating word analogies for top 300000 words in the model on ressources/questions-words.txt
# 2023-02-16 16:41:44,156 : INFO : capital-common-countries: 0.6% (1/156)
# 2023-02-16 16:41:44,463 : INFO : capital-world: 0.9% (1/111)
# 2023-02-16 16:41:44,514 : INFO : currency: 0.0% (0/18)
# 2023-02-16 16:41:45,140 : INFO : city-in-state: 0.0% (0/301)
# 2023-02-16 16:41:46,033 : INFO : family: 31.7% (133/420)

# %% [markdown]
# **When training the w2v models on the review dataset, since it hasn't been learnt with a lot of data, it does not perform very well.**

# %% [markdown]
# ## STEP 3: Loading a pre-trained model

# %% [markdown]
# In Gensim, embeddings are loaded and can be used via the ["KeyedVectors"](https://radimrehurek.com/gensim/models/keyedvectors.html) class
#
# > Since trained word vectors are independent from the way they were trained (Word2Vec, FastText, WordRank, VarEmbed etc), they can be represented by a standalone structure, as implemented in this module.
#
# >The structure is called “KeyedVectors” and is essentially a mapping between entities and vectors. Each entity is identified by its string id, so this is a mapping between {str => 1D numpy array}.
#
# >The entity typically corresponds to a word (so the mapping maps words to 1D vectors), but for some models, they key can also correspond to a document, a graph node etc. To generalize over different use-cases, this module calls the keys entities. Each entity is always represented by its string id, no matter whether the entity is a word, a document or a graph node.

# %%
# from gensim.test.utils import get_tmpfile
import gensim.downloader as api
from gensim.models import KeyedVectors

bload = True
fname = "word2vec-google-news-300"
sdir = "" # Change

if(bload==True):
    wv_pre_trained = KeyedVectors.load(sdir+fname+".dat")
else:
    wv_pre_trained = api.load(fname)
    wv_pre_trained.save(sdir+fname+".dat")

# %% [markdown]
# **Perform the "synctactic" and "semantic" evaluations again. Conclude on the pre-trained embeddings.**

# %%
wv_pre_trained
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 wv_pre_trained
#
# NameError: name 'wv_pre_trained' is not defined

# %% [markdown]
# ## STEP 4:  sentiment classification
#
# In the previous practical session, we used a bag of word approach to transform text into vectors.
# Here, we propose to try to use word vectors (previously learnt or loaded).
#
#
# ### <font color='green'> Since we have only word vectors and that sentences are made of multiple words, we need to aggregate them. </font>
#
#
# ### (1) Vectorize reviews using word vectors:
#
# Word aggregation can be done in different ways:
#
# - Sum
# - Average
# - Min/feature
# - Max/feature
#
# #### a few pointers:
#
# - `w2v.wv.vocab` is a `set()` of the vocabulary (all existing words in your model)
# - `np.minimum(a,b) and np.maximum(a,b)` respectively return element-wise min/max

# %%
w2v.wv.key_to_index
# Out:
# {'the': 0,
#  'a': 1,
#  'and': 2,
#  'of': 3,
#  'to': 4,
#  'is': 5,
#  'in': 6,
#  'I': 7,
#  'that': 8,
#  'this': 9,
#  'it': 10,
#  '/><br': 11,
#  'was': 12,
#  'as': 13,
#  'with': 14,
#  'for': 15,
#  'but': 16,
#  'The': 17,
#  'on': 18,
#  'movie': 19,
#  'are': 20,
#  'his': 21,
#  'film': 22,
#  'have': 23,
#  'not': 24,
#  'be': 25,
#  'you': 26,
#  'he': 27,
#  'by': 28,
#  'at': 29,
#  'one': 30,
#  'an': 31,
#  'from': 32,
#  'who': 33,
#  'like': 34,
#  'all': 35,
#  'they': 36,
#  'has': 37,
#  'so': 38,
#  'just': 39,
#  'about': 40,
#  'or': 41,
#  'her': 42,
#  'out': 43,
#  'some': 44,
#  'very': 45,
#  'more': 46,
#  'This': 47,
#  'would': 48,
#  'what': 49,
#  'when': 50,
#  'good': 51,
#  'only': 52,
#  'their': 53,
#  'It': 54,
#  'if': 55,
#  'had': 56,
#  'really': 57,
#  "it's": 58,
#  'which': 59,
#  'up': 60,
#  'even': 61,
#  'can': 62,
#  'were': 63,
#  'my': 64,
#  'see': 65,
#  'no': 66,
#  'she': 67,
#  'than': 68,
#  '-': 69,
#  'been': 70,
#  'there': 71,
#  'into': 72,
#  'get': 73,
#  'will': 74,
#  'story': 75,
#  'much': 76,
#  'because': 77,
#  'other': 78,
#  'most': 79,
#  'we': 80,
#  'time': 81,
#  'me': 82,
#  'make': 83,
#  'could': 84,
#  'also': 85,
#  'do': 86,
#  'how': 87,
#  'first': 88,
#  'people': 89,
#  'its': 90,
#  '/>The': 91,
#  'any': 92,
#  'great': 93,
#  "don't": 94,
#  'made': 95,
#  'think': 96,
#  'bad': 97,
#  'him': 98,
#  'being': 99,
#  'many': 100,
#  'never': 101,
#  'then': 102,
#  'But': 103,
#  'two': 104,
#  '<br': 105,
#  'too': 106,
#  'little': 107,
#  'after': 108,
#  'where': 109,
#  'way': 110,
#  'And': 111,
#  'it.': 112,
#  'them': 113,
#  'well': 114,
#  'your': 115,
#  'watch': 116,
#  'seen': 117,
#  'does': 118,
#  'movie.': 119,
#  'know': 120,
#  "It's": 121,
#  'character': 122,
#  'did': 123,
#  'characters': 124,
#  'movies': 125,
#  'best': 126,
#  'love': 127,
#  'ever': 128,
#  'over': 129,
#  'still': 130,
#  'A': 131,
#  'In': 132,
#  'should': 133,
#  'films': 134,
#  'plot': 135,
#  'such': 136,
#  'acting': 137,
#  'these': 138,
#  'i': 139,
#  'off': 140,
#  'show': 141,
#  'film.': 142,
#  'He': 143,
#  'better': 144,
#  "doesn't": 145,
#  'through': 146,
#  'say': 147,
#  'go': 148,
#  'those': 149,
#  'If': 150,
#  'something': 151,
#  'makes': 152,
#  "didn't": 153,
#  'There': 154,
#  'scene': 155,
#  'film,': 156,
#  'find': 157,
#  "I'm": 158,
#  'back': 159,
#  'movie,': 160,
#  'watching': 161,
#  'few': 162,
#  'real': 163,
#  'scenes': 164,
#  'actually': 165,
#  'going': 166,
#  'same': 167,
#  'life': 168,
#  '/>I': 169,
#  'quite': 170,
#  'lot': 171,
#  'look': 172,
#  'while': 173,
#  'want': 174,
#  '&': 175,
#  'end': 176,
#  'thing': 177,
#  'seems': 178,
#  'every': 179,
#  'got': 180,
#  'old': 181,
#  'why': 182,
#  'pretty': 183,
#  "can't": 184,
#  'man': 185,
#  'nothing': 186,
#  'actors': 187,
#  'another': 188,
#  'years': 189,
#  'between': 190,
#  'take': 191,
#  'before': 192,
#  'give': 193,
#  'may': 194,
#  'gets': 195,
#  'part': 196,
#  'young': 197,
#  'thought': 198,
#  "I've": 199,
#  'around': 200,
#  'things': 201,
#  'it,': 202,
#  "isn't": 203,
#  'without': 204,
#  'saw': 205,
#  'always': 206,
#  'own': 207,
#  'work': 208,
#  'almost': 209,
#  'must': 210,
#  'whole': 211,
#  'cast': 212,
#  'down': 213,
#  'might': 214,
#  'both': 215,
#  'new': 216,
#  'though': 217,
#  'us': 218,
#  'come': 219,
#  'They': 220,
#  'bit': 221,
#  'least': 222,
#  'here': 223,
#  'enough': 224,
#  'horror': 225,
#  'director': 226,
#  'feel': 227,
#  'big': 228,
#  'original': 229,
#  'am': 230,
#  'probably': 231,
#  'As': 232,
#  'fact': 233,
#  'rather': 234,
#  'kind': 235,
#  'far': 236,
#  'found': 237,
#  'long': 238,
#  'last': 239,
#  'funny': 240,
#  "that's": 241,
#  'comes': 242,
#  'anything': 243,
#  'since': 244,
#  'making': 245,
#  'trying': 246,
#  '"The': 247,
#  'each': 248,
#  'now': 249,
#  'action': 250,
#  'done': 251,
#  'interesting': 252,
#  'What': 253,
#  'You': 254,
#  'right': 255,
#  'She': 256,
#  'our': 257,
#  'worst': 258,
#  'looks': 259,
#  'point': 260,
#  'believe': 261,
#  'goes': 262,
#  'put': 263,
#  'played': 264,
#  "he's": 265,
#  '/>This': 266,
#  'main': 267,
#  "wasn't": 268,
#  'role': 269,
#  'guy': 270,
#  'family': 271,
#  'having': 272,
#  'series': 273,
#  'seem': 274,
#  'plays': 275,
#  'performance': 276,
#  'takes': 277,
#  'script': 278,
#  'hard': 279,
#  'world': 280,
#  'When': 281,
#  'watched': 282,
#  'worth': 283,
#  'minutes': 284,
#  'looking': 285,
#  'music': 286,
#  'different': 287,
#  'TV': 288,
#  'anyone': 289,
#  'especially': 290,
#  'shows': 291,
#  'sure': 292,
#  'away': 293,
#  'woman': 294,
#  'set': 295,
#  'someone': 296,
#  'times': 297,
#  'time.': 298,
#  'during': 299,
#  'yet': 300,
#  'left': 301,
#  'comedy': 302,
#  'John': 303,
#  'three': 304,
#  'girl': 305,
#  "there's": 306,
#  'simply': 307,
#  'American': 308,
#  'fun': 309,
#  'seeing': 310,
#  'completely': 311,
#  'reason': 312,
#  'play': 313,
#  "you're": 314,
#  'special': 315,
#  'used': 316,
#  'Not': 317,
#  'read': 318,
#  'again': 319,
#  'true': 320,
#  'One': 321,
#  'need': 322,
#  'For': 323,
#  'use': 324,
#  'sense': 325,
#  '--': 326,
#  'idea': 327,
#  'version': 328,
#  'everything': 329,
#  'place': 330,
#  'until': 331,
#  'given': 332,
#  'help': 333,
#  'So': 334,
#  'beautiful': 335,
#  'nice': 336,
#  'rest': 337,
#  'truly': 338,
#  'less': 339,
#  'job': 340,
#  'money': 341,
#  'came': 342,
#  'DVD': 343,
#  'recommend': 344,
#  'try': 345,
#  'We': 346,
#  'ending': 347,
#  'once': 348,
#  'That': 349,
#  'tell': 350,
#  'gives': 351,
#  'getting': 352,
#  'said': 353,
#  'shot': 354,
#  'second': 355,
#  'everyone': 356,
#  'My': 357,
#  'high': 358,
#  'himself': 359,
#  'excellent': 360,
#  'keep': 361,
#  'couple': 362,
#  'All': 363,
#  'actor': 364,
#  '(and': 365,
#  'enjoy': 366,
#  'half': 367,
#  'supposed': 368,
#  'become': 369,
#  'audience': 370,
#  'playing': 371,
#  'understand': 372,
#  'all,': 373,
#  'felt': 374,
#  'effects': 375,
#  'However,': 376,
#  'poor': 377,
#  'entire': 378,
#  'liked': 379,
#  "couldn't": 380,
#  'small': 381,
#  'early': 382,
#  'wife': 383,
#  'fan': 384,
#  'start': 385,
#  'went': 386,
#  'together': 387,
#  'doing': 388,
#  'against': 389,
#  'full': 390,
#  'remember': 391,
#  'book': 392,
#  'THE': 393,
#  'screen': 394,
#  'let': 395,
#  'Even': 396,
#  '2': 397,
#  'Hollywood': 398,
#  'absolutely': 399,
#  'definitely': 400,
#  'often': 401,
#  'is,': 402,
#  'time,': 403,
#  'becomes': 404,
#  'later': 405,
#  'sort': 406,
#  '10': 407,
#  'waste': 408,
#  'along': 409,
#  'day': 410,
#  'seemed': 411,
#  'year': 412,
#  'At': 413,
#  '\x96': 414,
#  'After': 415,
#  'His': 416,
#  'certainly': 417,
#  'next': 418,
#  'piece': 419,
#  'short': 420,
#  '.': 421,
#  'maybe': 422,
#  'several': 423,
#  'human': 424,
#  'black': 425,
#  'although': 426,
#  'else': 427,
#  'instead': 428,
#  'kids': 429,
#  'wanted': 430,
#  'wonderful': 431,
#  'camera': 432,
#  'production': 433,
#  'course': 434,
#  'that,': 435,
#  'performances': 436,
#  'loved': 437,
#  'them.': 438,
#  'classic': 439,
#  'tries': 440,
#  'To': 441,
#  'totally': 442,
#  'father': 443,
#  'women': 444,
#  'men': 445,
#  'able': 446,
#  'wants': 447,
#  "I'd": 448,
#  'live': 449,
#  'mind': 450,
#  'home': 451,
#  'called': 452,
#  'gave': 453,
#  'hope': 454,
#  'line': 455,
#  'top': 456,
#  'enjoyed': 457,
#  'already': 458,
#  'person': 459,
#  'based': 460,
#  'friends': 461,
#  'turn': 462,
#  'story,': 463,
#  'video': 464,
#  'starts': 465,
#  'perfect': 466,
#  '(the': 467,
#  'one.': 468,
#  'New': 469,
#  'turns': 470,
#  'under': 471,
#  'final': 472,
#  'this.': 473,
#  "won't": 474,
#  'name': 475,
#  'problem': 476,
#  'While': 477,
#  'sex': 478,
#  'care': 479,
#  'episode': 480,
#  'mean': 481,
#  'him.': 482,
#  'me.': 483,
#  'moments': 484,
#  'written': 485,
#  'low': 486,
#  'finally': 487,
#  'lost': 488,
#  'either': 489,
#  'stupid': 490,
#  'lead': 491,
#  'Michael': 492,
#  'lines': 493,
#  'favorite': 494,
#  'took': 495,
#  'behind': 496,
#  'this,': 497,
#  'cannot': 498,
#  "she's": 499,
#  'face': 500,
#  'Of': 501,
#  'No': 502,
#  'head': 503,
#  "you'll": 504,
#  'story.': 505,
#  'budget': 506,
#  'stars': 507,
#  'well.': 508,
#  'title': 509,
#  'good.': 510,
#  'sound': 511,
#  'fine': 512,
#  'guess': 513,
#  'death': 514,
#  'Some': 515,
#  'school': 516,
#  "they're": 517,
#  'me,': 518,
#  'all.': 519,
#  "film's": 520,
#  'How': 521,
#  'night': 522,
#  'dialogue': 523,
#  'extremely': 524,
#  'lack': 525,
#  'heard': 526,
#  'beginning': 527,
#  'style': 528,
#  'life.': 529,
#  'itself': 530,
#  'terrible': 531,
#  'star': 532,
#  'feeling': 533,
#  'perhaps': 534,
#  'house': 535,
#  'others': 536,
#  'works': 537,
#  'boring': 538,
#  "wouldn't": 539,
#  'attempt': 540,
#  'expect': 541,
#  'decent': 542,
#  'looked': 543,
#  'kill': 544,
#  'course,': 545,
#  'lives': 546,
#  'good,': 547,
#  'Mr.': 548,
#  "There's": 549,
#  '/>In': 550,
#  'quality': 551,
#  'late': 552,
#  'friend': 553,
#  'Then': 554,
#  'With': 555,
#  'entertaining': 556,
#  'well,': 557,
#  '/>It': 558,
#  'Just': 559,
#  'particularly': 560,
#  'fans': 561,
#  'fight': 562,
#  'wrong': 563,
#  'thinking': 564,
#  'highly': 565,
#  'viewer': 566,
#  'case': 567,
#  'finds': 568,
#  'complete': 569,
#  'whose': 570,
#  'directed': 571,
#  'throughout': 572,
#  'taken': 573,
#  'leave': 574,
#  'obviously': 575,
#  'writing': 576,
#  'amazing': 577,
#  'exactly': 578,
#  'guys': 579,
#  '/>If': 580,
#  'somewhat': 581,
#  'movies.': 582,
#  'awful': 583,
#  'says': 584,
#  'shown': 585,
#  'evil': 586,
#  'obvious': 587,
#  'Why': 588,
#  '3': 589,
#  'laugh': 590,
#  'told': 591,
#  'movies,': 592,
#  'James': 593,
#  'boy': 594,
#  'run': 595,
#  'past': 596,
#  'close': 597,
#  'films,': 598,
#  'number': 599,
#  'parts': 600,
#  'wonder': 601,
#  'however,': 602,
#  'type': 603,
#  'group': 604,
#  'across': 605,
#  'opening': 606,
#  'car': 607,
#  'picture': 608,
#  'mother': 609,
#  'acting,': 610,
#  'soon': 611,
#  'white': 612,
#  'dead': 613,
#  'sometimes': 614,
#  'war': 615,
#  'save': 616,
#  'turned': 617,
#  'tells': 618,
#  'coming': 619,
#  'despite': 620,
#  'known': 621,
#  'worse': 622,
#  'started': 623,
#  'strong': 624,
#  'direction': 625,
#  'that.': 626,
#  'local': 627,
#  'killer': 628,
#  'side': 629,
#  'taking': 630,
#  'hour': 631,
#  'wish': 632,
#  'children': 633,
#  'knew': 634,
#  'myself': 635,
#  ',': 636,
#  'huge': 637,
#  'stop': 638,
#  'happens': 639,
#  'except': 640,
#  'running': 641,
#  'it.<br': 642,
#  'act': 643,
#  'here.': 644,
#  'killed': 645,
#  'usually': 646,
#  'single': 647,
#  'female': 648,
#  'bad.': 649,
#  "aren't": 650,
#  'way,': 651,
#  'stories': 652,
#  'girls': 653,
#  'fact,': 654,
#  'including': 655,
#  'supporting': 656,
#  'British': 657,
#  'major': 658,
#  'bring': 659,
#  'David': 660,
#  '/>There': 661,
#  'involved': 662,
#  'dark': 663,
#  'due': 664,
#  'Robert': 665,
#  'humor': 666,
#  'characters,': 667,
#  'voice': 668,
#  'town': 669,
#  'talking': 670,
#  'out.': 671,
#  'hit': 672,
#  'call': 673,
#  'game': 674,
#  'brilliant': 675,
#  "Don't": 676,
#  '!': 677,
#  'musical': 678,
#  'falls': 679,
#  'giving': 680,
#  'end,': 681,
#  'and,': 682,
#  'actress': 683,
#  'relationship': 684,
#  "I'll": 685,
#  'ends': 686,
#  'son': 687,
#  'saying': 688,
#  'again.': 689,
#  'clearly': 690,
#  'mostly': 691,
#  'living': 692,
#  'Well,': 693,
#  'one,': 694,
#  'easily': 695,
#  'serious': 696,
#  'police': 697,
#  'matter': 698,
#  'order': 699,
#  'drama': 700,
#  'feels': 701,
#  'themselves': 702,
#  'appears': 703,
#  'bad,': 704,
#  'actual': 705,
#  'needs': 706,
#  'example': 707,
#  'moment': 708,
#  'similar': 709,
#  'important': 710,
#  'change': 711,
#  'chance': 712,
#  'end.': 713,
#  'modern': 714,
#  'nearly': 715,
#  'child': 716,
#  "haven't": 717,
#  'is.': 718,
#  'cinema': 719,
#  'comic': 720,
#  'history': 721,
#  '/>But': 722,
#  'Although': 723,
#  'On': 724,
#  'seen.': 725,
#  'horrible': 726,
#  'way.': 727,
#  '/>': 728,
#  'art': 729,
#  'named': 730,
#  'heart': 731,
#  'mention': 732,
#  'her.': 733,
#  'movie.<br': 734,
#  'interest': 735,
#  "That's": 736,
#  'beyond': 737,
#  'released': 738,
#  'happened': 739,
#  'English': 740,
#  'knows': 741,
#  'kept': 742,
#  'cut': 743,
#  'here,': 744,
#  'usual': 745,
#  'kid': 746,
#  'stuff': 747,
#  'plot,': 748,
#  'using': 749,
#  'brought': 750,
#  'again,': 751,
#  'slow': 752,
#  'within': 753,
#  'films.': 754,
#  'simple': 755,
#  'typical': 756,
#  'romantic': 757,
#  'eyes': 758,
#  'bunch': 759,
#  'certain': 760,
#  'tried': 761,
#  'hours': 762,
#  'him,': 763,
#  'showing': 764,
#  'whether': 765,
#  'near': 766,
#  '/>A': 767,
#  'upon': 768,
#  'fall': 769,
#  'film.<br': 770,
#  'strange': 771,
#  'George': 772,
#  'events': 773,
#  'life,': 774,
#  'score': 775,
#  'decided': 776,
#  'shots': 777,
#  '/>As': 778,
#  'body': 779,
#  'working': 780,
#  'four': 781,
#  'among': 782,
#  'Jack': 783,
#  'Her': 784,
#  'yourself': 785,
#  'surprised': 786,
#  'hear': 787,
#  'begins': 788,
#  '(I': 789,
#  'five': 790,
#  'on.': 791,
#  'sad': 792,
#  '(as': 793,
#  'greatest': 794,
#  'cheap': 795,
#  'became': 796,
#  'Paul': 797,
#  'Richard': 798,
#  'happen': 799,
#  'none': 800,
#  'famous': 801,
#  'song': 802,
#  'Maybe': 803,
#  'learn': 804,
#  'middle': 805,
#  '/>And': 806,
#  'annoying': 807,
#  'daughter': 808,
#  'happy': 809,
#  'days': 810,
#  'jokes': 811,
#  'sit': 812,
#  'stay': 813,
#  'basically': 814,
#  'sets': 815,
#  'too.': 816,
#  'experience': 817,
#  'Peter': 818,
#  'songs': 819,
#  'murder': 820,
#  "/>It's": 821,
#  'sequence': 822,
#  '(which': 823,
#  'attention': 824,
#  '1': 825,
#  'funny.': 826,
#  'sexual': 827,
#  'lots': 828,
#  'talk': 829,
#  'above': 830,
#  'buy': 831,
#  'documentary': 832,
#  'stand': 833,
#  'easy': 834,
#  'view': 835,
#  'From': 836,
#  'funny,': 837,
#  'hate': 838,
#  'difficult': 839,
#  'light': 840,
#  'clear': 841,
#  'realize': 842,
#  'leaves': 843,
#  'husband': 844,
#  'means': 845,
#  'keeps': 846,
#  'elements': 847,
#  'characters.': 848,
#  'episodes': 849,
#  'Now': 850,
#  'meets': 851,
#  'brother': 852,
#  'alone': 853,
#  'Its': 854,
#  'cinematography': 855,
#  '5': 856,
#  'genre': 857,
#  'character,': 858,
#  'roles': 859,
#  'Japanese': 860,
#  'figure': 861,
#  'word': 862,
#  'out,': 863,
#  'These': 864,
#  'ones': 865,
#  'them,': 866,
#  'violence': 867,
#  'flick': 868,
#  'hand': 869,
#  'First': 870,
#  'poorly': 871,
#  'possibly': 872,
#  'brings': 873,
#  'doubt': 874,
#  'age': 875,
#  'emotional': 876,
#  'silly': 877,
#  'say,': 878,
#  'move': 879,
#  "you've": 880,
#  'Is': 881,
#  'possible': 882,
#  'nor': 883,
#  'French': 884,
#  'NOT': 885,
#  'theme': 886,
#  'problems': 887,
#  'ten': 888,
#  'previous': 889,
#  'on,': 890,
#  'Like': 891,
#  'novel': 892,
#  "who's": 893,
#  'killing': 894,
#  'reality': 895,
#  'leads': 896,
#  'moving': 897,
#  'apparently': 898,
#  'straight': 899,
#  'television': 900,
#  'talent': 901,
#  'comments': 902,
#  'add': 903,
#  'towards': 904,
#  'career': 905,
#  '(or': 906,
#  'Most': 907,
#  'better.': 908,
#  'level': 909,
#  'message': 910,
#  'deal': 911,
#  'reading': 912,
#  'overall': 913,
#  'enjoyable': 914,
#  'Oscar': 915,
#  'Tom': 916,
#  'write': 917,
#  'An': 918,
#  'ridiculous': 919,
#  'various': 920,
#  'review': 921,
#  'meant': 922,
#  'herself': 923,
#  'needed': 924,
#  'cool': 925,
#  'filmed': 926,
#  'gore': 927,
#  'work.': 928,
#  'create': 929,
#  'leading': 930,
#  'though,': 931,
#  'blood': 932,
#  'incredibly': 933,
#  'somehow': 934,
#  'begin': 935,
#  'personal': 936,
#  'feature': 937,
#  'room': 938,
#  'watch.': 939,
#  'manages': 940,
#  '4': 941,
#  'forced': 942,
#  'whom': 943,
#  'hell': 944,
#  'Also': 945,
#  'animation': 946,
#  'form': 947,
#  'particular': 948,
#  'show.': 949,
#  'eventually': 950,
#  'future': 951,
#  'up.': 952,
#  'appear': 953,
#  'hero': 954,
#  "He's": 955,
#  'points': 956,
#  'writer': 957,
#  'third': 958,
#  'there.': 959,
#  'interested': 960,
#  'fairly': 961,
#  'effort': 962,
#  'scary': 963,
#  'meet': 964,
#  'rent': 965,
#  'hilarious': 966,
#  'older': 967,
#  'expecting': 968,
#  'her,': 969,
#  'plenty': 970,
#  'dramatic': 971,
#  'you.': 972,
#  'viewers': 973,
#  'subject': 974,
#  'reviews': 975,
#  'team': 976,
#  'weak': 977,
#  'scenes,': 978,
#  'attempts': 979,
#  'power': 980,
#  'hardly': 981,
#  'political': 982,
#  'follow': 983,
#  'male': 984,
#  'Joe': 985,
#  'features': 986,
#  'scene,': 987,
#  'York': 988,
#  'Also,': 989,
#  'tale': 990,
#  'decides': 991,
#  'worked': 992,
#  'average': 993,
#  'premise': 994,
#  'up,': 995,
#  'imagine': 996,
#  'total': 997,
#  'Lee': 998,
#  'country': 999,
#  ...}

# %%
w2v.wv

# %%
import numpy as np
# We first need to vectorize text:
# First we propose to a sum of them

def get_train_test_set(agg_func):
    def vectorize(text, mean=False):
        """
        This function should vectorize one review

        input: str
        output: np.array(float)
        """    
        vec = []
        for word in text.split():
            try:
                vec.append(w2v.wv[word])
            except KeyError:
                continue
        return agg_func(np.array(vec), axis=0)

    classes = [pol for text,pol in train]
    X = [vectorize(text) for text,pol in train]
    X_test = [vectorize(text) for text,pol in test]
    true = [pol for text,pol in test]

    return X, X_test, classes, true

# %%
X_train, X_test, y_train, y_test = get_train_test_set(np.mean)

# %%
#let's see what a review vector looks like.
X[0]
# Out:
# array([  0.9962789 ,  11.440914  ,   1.8048078 ,  -0.1913385 ,
#          0.85355127, -24.18671   ,  16.140886  ,  37.643944  ,
#        -34.91759   , -23.692745  ,  -1.1175997 , -25.628988  ,
#         -1.3991727 ,  18.307074  ,   7.7939153 ,  -9.873245  ,
#          5.995385  , -11.069575  ,  -5.351398  , -43.677418  ,
#         17.827225  ,   8.9137125 ,  14.733991  , -18.565659  ,
#         10.744837  ,  -4.4008193 , -15.416159  ,   1.1796215 ,
#        -16.153578  ,  21.468283  ,  26.662832  , -11.013621  ,
#          7.774525  , -25.564692  ,  -6.052724  ,  17.006271  ,
#         -5.6226754 ,  12.455929  , -14.924302  , -13.561244  ,
#         17.20747   ,  -9.256992  ,  -8.899597  ,   0.8016176 ,
#          9.517336  ,  -4.8509493 , -17.599451  ,  -6.102292  ,
#         21.656157  ,  20.079906  ,   7.9809413 , -20.20644   ,
#         -2.7865844 ,   0.7548676 ,  -2.295291  ,  13.713524  ,
#          7.071466  ,  14.156362  , -23.193888  ,  10.417994  ,
#         -5.4104767 ,  -4.888612  ,  26.078571  ,   6.823675  ,
#        -10.872923  ,  25.355438  ,   2.0167482 ,   8.20766   ,
#        -19.37421   ,  15.278552  ,   4.0764723 ,  11.85118   ,
#         14.761031  ,   5.2638364 ,  14.23595   ,  -3.8604572 ,
#         22.76993   , -11.253841  ,  -7.013881  ,  -1.6652628 ,
#        -23.725357  ,  -6.008808  , -15.217388  ,  20.762642  ,
#         -5.0928717 ,  -6.765602  ,  12.192293  ,  14.766841  ,
#         18.085434  ,  15.533247  ,  38.788345  ,  -1.6931391 ,
#         -6.046599  ,  -0.8778338 ,  24.227097  ,  -2.900755  ,
#          1.9820838 , -21.899399  ,   0.7339283 ,  -5.7543    ],
#       dtype=float32)

# %% [markdown]
# ### (2) Train a classifier
# as in the previous practical session, train a logistic regression to do sentiment classification with word vectors

# %%
np.unique(y_test)
# Out:
# array([0, 1])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Scikit Logistic Regression
def eval(agg_func):
    X_train, X_test, y_train, y_test = get_train_test_set(agg_func)
    lr = LogisticRegression(random_state=0)
    lr.fit(X_train, y_train)
    return lr.score(X_test, y_test)

print(f"""
sum : {eval(np.sum)}
mean : {eval(np.mean)}
min : {eval(np.min)}
max : {eval(np.max)}
""")
# Out:
# /home/charles/.pyenv/versions/3.10.10/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/charles/.pyenv/versions/3.10.10/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/charles/.pyenv/versions/3.10.10/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# sum : 0.82284
# mean : 0.817
# min : 0.70212
# max : 0.71076
# /home/charles/.pyenv/versions/3.10.10/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# performance should be worst than with bag of word (~80%). Sum/Mean aggregation does not work well on long reviews (especially with many frequent words). This adds a lot of noise.
#
# ## **Todo** :  Try answering the following questions:
#
# - Which word2vec model works best: skip-gram or cbow
# - Do pretrained vectors work best than those learnt on the train dataset ?

# %% [markdown]
# **(Bonus)** To have a better accuracy, we could try two things:
# - Better aggregation methods (weight by tf-idf ?)
# - Another word vectorizing method such as [fasttext](https://radimrehurek.com/gensim/models/fasttext.html)
# - A document vectorizing method such as [Doc2Vec](https://radimrehurek.com/gensim/models/doc2vec.html)
